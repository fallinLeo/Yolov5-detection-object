# %% [markdown]
# <a href="https://colab.research.google.com/github/fallinLeo/Yolov5-detection-object/blob/main/YOLOV5_Customtraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.flush_and_unmount()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive #yolov5 cloning code
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !git reset --hard fbe67e465375231474a2ad80a4389efc77ecff99  # YOLOv5 브랜치 설정
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive #yolov5 cloning code'
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15829, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 15829 (delta 21), reused 35 (delta 16), pack-reused 15768
# Receiving objects: 100% (15829/15829), 14.65 MiB | 11.47 MiB/s, done.
# Resolving deltas: 100% (10833/10833), done.
# /content/yolov5
# HEAD is now at fbe67e4 Fix `OMP_NUM_THREADS=1` for macOS (#8624)

# %%
import zipfile #training unzip code
# %cd /content/drive/MyDrive/test/train
# !unzip "Train.zip"
# Out:
# /content/drive/MyDrive/test/train
# unzip:  cannot find or open Train.zip, Train.zip.zip or Train.zip.ZIP.

# %%
import zipfile #validing unzip code
# %cd /content/drive/MyDrive/test/valid
# !unzip -qq "/content/drive/MyDrive/test/valid.zip"
# Out:
# /content/drive/MyDrive/test/valid

# %%
import os
import glob # dataset remove code

[os.remove(f) for f in glob.glob('/content/drive/MyDrive/test/valid/*.jpg')] #jpg파일
[os.remove(f) for f in glob.glob('/content/drive/MyDrive/test/valid/*.txt')] #txt파일
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
import glob
path = '/content/drive/MyDrive/test/valid/*.jpg'
file = glob.glob(path)
print(len(file))
# Out:
# 0

# %%
import glob
path = '/content/drive/MyDrive/test/train/train/*.txt'
file = glob.glob(path)
print(len(file))
# Out:
# 0

# %%
# %cat /content/drive/MyDrive/yolov5/data/data.yaml
# Out:
# train: /content/drive/MyDrive/test/train/train
# val: /content/drive/MyDrive/test/valid
#
# nc: 5
# names: ['green','left','red','straightleft','yellow']

# %%
# %cd /D/traffic_light/valid
# Out:
# [Errno 2] No such file or directory: '/D/traffic_light/valid'
# /content/drive/MyDrive/test/valid

# %%
# %cd /content/drive/MyDrive/yolov5/
# !pip install -r requirements.txt
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/yolov5/'
# /content
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# %cd /content/drive/MyDrive/yolov5
# !python /content/drive/MyDrive/yolov5/train.py --img 416 --batch 16 --epochs 50 --data /content/drive/MyDrive/yolov5/data/data.yaml --cfg /content/drive/MyDrive/yolov5/models/yolov5s.yaml --name traffic_light_test
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/yolov5'
# /content
# python3: can't open file '/content/drive/MyDrive/yolov5/train.py': [Errno 2] No such file or directory
